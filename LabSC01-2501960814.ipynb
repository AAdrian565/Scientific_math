# %% [markdown]
# # **BASICS**

# %%
import time
print (time.ctime())
# Out:
# Wed Feb 23 02:29:37 2022

# %%
x=1
x
x+=1
x
# Out:
# 2

# %% [markdown]
# # **Intro to numpy**

# %%
import numpy as np
x = np.array([[1,4,3],[2,5,6]])
x
# Out:
# array([[1, 4, 3],
#        [2, 5, 6]])

# %% [markdown]
# # **Function**

# %%
def sumabc(a,b,c):
  return a+b+c

sumabc(2,4,3)
# Out:
# 9

# %%
def isgreater(n,x):
    if n < x-5:
        status = "heat"
    elif n > x+5:
        status = "AC"
    else:
        status = "Off"
    return status

status = isgreater(65,80)
status
# Out:
# 'heat'

# %% [markdown]
# # **Else If**

# %%
x = 3
if x>1 and x<2:
    y = 2
elif x>2 and x<4:
    y = 4
else: 
    y=0

y
# Out:
# 4

# %%
x = 3
if 1<x<2:
    y=2
elif 2<x<4:
    y=4
else:
    y=0
y
# Out:
# 4

# %% [markdown]
# # **STRING**

# %%
nama = "First Middle Last"
absen = "5"
print(nama.upper())
print(nama.lower())

print("Nama/absen : " + nama + "/" + absen)
# Out:
# FIRST MIDDLE LAST
# first middle last
# Nama/absen : First Middle Last/5
